# %%
import pickle
from config import Config
import main
import os

name = Config.SETS
name = [str(n) for n in name]


def load_pkl_files(base_dir):
    data = {}
    for root, dirs, files in os.walk(base_dir):
        for file in files:
            if file.endswith(".pkl"):
                set_name = os.path.basename(os.path.dirname(root))
                file_path = os.path.join(root, file)
                with open(file_path, 'rb') as f:
                    pkl_content = pickle.load(f)
                if set_name not in data:
                    data[set_name] = []
                data[set_name].append(pkl_content)
    return data


SCRIPT_DIR = os.path.dirname(os.path.realpath(__file__))
result_name = 'results_20250118_212753'
base_directory = os.path.join(SCRIPT_DIR, '..', 'data', 'output', result_name)
pkl_data = load_pkl_files(base_directory)

# %%
pkl_data
