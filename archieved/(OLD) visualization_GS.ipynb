# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from scipy.io import loadmat
import networkx as nx
from scipy.sparse import csr_matrix
import warnings
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
cd /content/drive/MyDrive/vis/vis
# Out:
# /content/drive/.shortcut-targets-by-id/1fbFJ_bWqldola2R1e_xMJLKIBCyM24wh/vis/vis

# %% [markdown]
# # Load Graph

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# Load network data
network_path = '/content/drive/MyDrive/vis/vis/20kX/sparse_matrices_20kX_new.npz'
network_data = np.load(network_path, allow_pickle=True)
edges = network_data['A'].item()  i
rows, cols = edges.nonzero()

# Load node positions
positions_path = '/content/drive/MyDrive/vis/vis/20kX_postion.npy'
positions = np.load(positions_path, allow_pickle=True)
positions[:, [0, 1]] = positions[:, [1, 0]]  # Swap columns to fit the plotting needs

# Get min and max coordinates for normalization
min_x = positions[:, 0].min()
max_x = positions[:, 0].max()
min_y = positions[:, 1].min()
max_y = positions[:, 1].max()

# Normalize function
def normalize(value, min_value, max_value):
    return (value - min_value) / (max_value - min_value)

# Load and resize image
canvas_image_path = '/content/drive/MyDrive/vis/vis/20kX/Copy of 300kV 20kX  Pre-GIF 2045.tif'
raw_src = cv2.imread(canvas_image_path, cv2.IMREAD_GRAYSCALE)

h, w = raw_src.shape
scalefactor = 512 / max(w, h)
swidth = int(scalefactor * w)
sheight = int(scalefactor * h)
dsize = (swidth, sheight)
canvas_image_gray = cv2.resize(raw_src, dsize)

canvas_height, canvas_width = canvas_image_gray.shape

# Normalize and scale positions
scaled_positions = np.zeros_like(positions)
scaled_positions[:, 0] = normalize(positions[:, 0], min_x, max_x) * canvas_width
scaled_positions[:, 1] = normalize(positions[:, 1], min_y, max_y) * canvas_height

# Convert positions to a dictionary for easier access
position_dict = {i: pos for i, pos in enumerate(scaled_positions)}

# Plot image and network
plt.figure(figsize=(10, 10))
plt.imshow(canvas_image_gray, cmap='gray')

# Plot edges
for s, e in zip(rows, cols):
    if s in position_dict and e in position_dict:
        x1, y1 = position_dict[s]
        x2, y2 = position_dict[e]
        plt.plot([x1, x2], [y1, y2], color='lime', linewidth=2)

# Plot nodes
for (x, y) in scaled_positions:
    plt.plot(x, y, 'o', color = '#4169E1', markersize=4)

plt.axis('off')
plt.show()

# %% [markdown]
# # Model Construction

# %%
import networkx as nx
import matplotlib.pyplot as plt

n = 100
m = 3
BA_model = nx.barabasi_albert_graph(n, m)

plt.figure(figsize=(10, 10))
pos = nx.spring_layout(BA_model)
nx.draw(BA_model, pos, node_size=50, node_color='skyblue', with_labels=False, edge_color='gray')
plt.title("Barabási-Albert Model Network")
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

n = 15
m = 2
BA_model = nx.barabasi_albert_graph(n, m)

plt.figure(figsize=(8, 8))
pos = nx.spring_layout(BA_model)
nx.draw(BA_model, pos, node_size=300, node_color='skyblue', with_labels=True, font_size=10, edge_color='gray')
plt.title("Barabási-Albert Model Network")
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

n = 20
m = 1
BA_model = nx.barabasi_albert_graph(n, m)

plt.figure(figsize=(8, 8))
pos = nx.spring_layout(BA_model)
nx.draw(BA_model, pos, node_size=300, node_color='skyblue', with_labels=True, font_size=10, edge_color='gray')
plt.title("Barabási-Albert Model Network")
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

n = 15
m = 1
BA_model = nx.barabasi_albert_graph(n, m)

plt.figure(figsize=(8, 8))
pos = nx.spring_layout(BA_model)
nx.draw(BA_model, pos, node_size=300, node_color='skyblue', with_labels=True, font_size=10, edge_color='gray')
plt.title("Barabási-Albert Model Network")
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

n = 20
m = 3
BA_model = nx.barabasi_albert_graph(n, m)

plt.figure(figsize=(8, 8))
pos = nx.spring_layout(BA_model)
nx.draw(BA_model, pos, node_size=300, node_color='skyblue', with_labels=True, font_size=10, edge_color='gray')
plt.title("Barabási-Albert Model Network")
plt.show()
